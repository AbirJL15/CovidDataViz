# %%
import pandas as pd

# %%
df=pd.read_csv('worldometer_data.csv')

# %%
df.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
#total cases for Asia continent
df[df['Continent']=='Europe']['Tot Cases/1M pop'].sum()
# Out:
# np.float64(209454.0)

# %%
df[df['Continent']=='North America']['TotalCases'].sum()
# Out:
# np.int64(5919209)

# %%
#total cases for Asia continent
df[df['Continent']=='Africa']['TotalCases'].sum()
# Out:
# np.int64(1011867)

# %%
print(df[df['Country/Region']=='USA']['TotalRecovered'].sum())
# Out:
# 2576668.0

# %%
print(df[df['Country/Region']=='Russia']['TotalCases'])
# Out:
# 3    871894
# Name: TotalCases, dtype: int64

# %%
df[df['Continent']=='Africa']['TotalDeaths'].sum()
# Out:
# np.float64(22114.0)

# %%
df[df['Continent']=='Africa']['TotalRecovered'].sum()
# Out:
# np.float64(693620.0)

# %%
#total cases for Asia continent
#print(df[df['Country/Region']=='Colombia']['TotalDeaths'])
print(df[df['Country/Region']=='Colombia']['TotalRecovered'])
# Out:
# 8    192355.0
# Name: TotalRecovered, dtype: float64

# %%
df[df['Country/Region']=='Spain']
# Out:
#   Country/Region Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 9          Spain    Europe  46756648.0      354530       NaN      28500.0
#
#    NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 9        NaN             NaN           NaN          NaN             617.0
#
#    Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop WHO Region
# 9            7582.0          610.0   7064329.0      151087.0     Europe

# %%
#total cases for Asia continent
df[df['Continent']=='Asia']['TotalRecovered'].sum()
# Out:
# np.float64(3508170.0)

# %%
#total cases for Asia continent
df[df['Continent']=='North America']['TotalCases'].sum()
# Out:
# np.int64(5919209)

# %%
df[df['Continent']=='Australia/Oceania']['TotalDeaths'].sum()
# Out:
# np.float64(281.0)

# %%
#total cases for Asia continent
df[df['Continent']=='Africa']['TotalCases'].sum()
# Out:
# np.int64(1011867)

# %%
df[df['Continent']=='Africa']
# Out:
#             Country/Region Continent   Population  TotalCases  NewCases  \
# 4             South Africa    Africa   59381566.0      538184       NaN
# 26                   Egypt    Africa  102516525.0       95006       NaN
# 45                 Nigeria    Africa  206606300.0       45244       NaN
# 50                   Ghana    Africa   31133483.0       39642       NaN
# 54                 Algeria    Africa   43926079.0       33626       NaN
# 56                 Morocco    Africa   36953359.0       29644       NaN
# 61                   Kenya    Africa   53881160.0       24411       NaN
# 66                Ethiopia    Africa  115223736.0       20900       NaN
# 70                Cameroon    Africa   26606188.0       17718       NaN
# 71             Ivory Coast    Africa   26437950.0       16447       NaN
# 77              Madagascar    Africa   27755708.0       12526       NaN
# 78                   Sudan    Africa   43943536.0       11780       NaN
# ...

# %%
df[df['Continent']=="North America"]['TotalDeaths'].sum()
# Out:
# np.float64(229855.0)

# %%
df['Continent'].unique()
# Out:
# array(['North America', 'South America', 'Asia', 'Europe', 'Africa',
#        'Australia/Oceania', nan], dtype=object)

# %%
df[df['Continent']=="Australia/Oceania"]['TotalCases'].sum()
# Out:
# np.int64(21735)

# %%
#Data visualization

# %%
df1=pd.read_csv('/content/covid_19_clean_complete.csv')

# %%
df1.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
#Merge dataframes on Country/Region column
df2=pd.merge(df,df1,on='Country/Region')

# %%
df2.head()
# Out:
#   Country/Region      Continent   Population  TotalCases  NewCases  \
# 0         Brazil  South America  212710692.0     2917562       NaN
# 1         Brazil  South America  212710692.0     2917562       NaN
# 2         Brazil  South America  212710692.0     2917562       NaN
# 3         Brazil  South America  212710692.0     2917562       NaN
# 4         Brazil  South America  212710692.0     2917562       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  ...  \
# 0      98644.0        NaN       2047660.0           NaN     771258.0  ...
# 1      98644.0        NaN       2047660.0           NaN     771258.0  ...
# 2      98644.0        NaN       2047660.0           NaN     771258.0  ...
# 3      98644.0        NaN       2047660.0           NaN     771258.0  ...
# 4      98644.0        NaN       2047660.0           NaN     771258.0  ...
#
#    WHO Region_x  Province/State     Lat     Long        Date Confirmed Deaths  \
# ...

# %%
#Keep a few columns only
df2=df2[['Country/Region','Continent','Lat','Long' ,'TotalCases','TotalDeaths','TotalRecovered','Date']]

# %%
#Convert to CSV
df2.to_csv('covid_19_data.csv')

# %%
#Number of cases for country India (last appearance)
df2[df2['Country/Region']=='France']['TotalCases'].value_counts()
# Out:
# TotalCases
# 195633    2068
# Name: count, dtype: int64

# %%
df3=pd.read_csv('day_wise.csv')

# %%
df3.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
len(df3)
# Out:
# 188

# %%
df3['Date'].unique()
# Out:
# array(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25',
#        '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29',
#        '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02',
#        '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#        '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#        '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14',
#        '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18',
#        '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22',
#        '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26',
#        '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#        '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#        '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#        '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#        '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21',
# ...

# %%
df3['Date'] = pd.to_datetime(df3['Date'])

# %%
df3['Date'].dt.year.value_counts()
# Out:
# Date
# 2020    188
# Name: count, dtype: int64

# %%
df3['Date'].dt.month.value_counts()
# Out:
# Date
# 3    31
# 5    31
# 4    30
# 6    30
# 2    29
# 7    27
# 1    10
# Name: count, dtype: int64

# %%
#print last 5 lines
df3[df3['Date'].dt.month == 6].tail()
# Out:
#           Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 156 2020-06-26    9777487  494782    4875774  4406931     191346        4827
# 157 2020-06-27    9955597  499268    4981808  4474521     178110        4486
# 158 2020-06-28   10117227  502357    5070592  4544278     162349        3089
# 159 2020-06-29   10275799  506078    5164494  4605227     158572        3721
# 160 2020-06-30   10449697  511210    5281459  4657028     173898        5132
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 156         106316                5.06                  49.87
# 157         106034                5.01                  50.04
# 158          88784                4.97                  50.12
# 159          93902                4.92                  50.26
# 160         116965                4.89                  50.54
#
#      Deaths / 100 Recovered  No. of countries
# 156                   10.15               187
# ...
